# %% [markdown]
# # References
#
# ###  For more info on SHAP (SHapley Additive exPlanations) see
#
# - https://github.com/slundberg/shap
# - http://papers.nips.cc/paper/7062-a-unified-approach-to-interpreting-model-predictions
# - https://christophm.github.io/interpretable-ml-book/shapley.html
#
# ### More about Plotly Dash
#
# - https://dash.plot.ly/

# %% [markdown]
# # Read Data

# %%
import pandas as pd

feature_names=["Age", "Workclass", "Final Weight", "Education", "Education-Num", "Marital Status",
               "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
               "Hours per week", "Country", "Income"]

df_train=pd.read_csv("../data/adult.data",
                     names=feature_names)

df_test=pd.read_csv("../data/adult.test",
                    skiprows =1,
                    names=feature_names)

# %% [markdown]
# # Data prep & problem definition

# %%
def df_prep(df):    
    LABEL="Income"
    y_train=df[LABEL].replace([" <=50K"," <=50K."," >50K"," >50K."],[0,0,1,1])
    df_X=df.drop(LABEL, axis=1)
    return df_X,y_train

df_X_train,y_train=df_prep(df_train)
df_X_test,y_test=df_prep(df_test)

# %% [markdown]
# # Load trained model

# %% [markdown]
# ## Load with joblib

# %%
import os
import joblib

def load_model(model_id):
    
    load_path=f"../models/{model_id}.pickle"
    return joblib.load(load_path)
   
model=load_model("adult_randomforest")
model
# Out:
# Pipeline(memory=None,
#      steps=[('featurize', DataFrameMapper(default=False, df_out=True,
#         features=[(['Age'], Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0), {}), (['Final Weight'], Imputer(axis=0, copy=True, missing_values='NaN', strategy='mean', verbose=0), {}), (['Education-Num'], Im...imators=500, n_jobs=-1, oob_score=False, random_state=42,
#             verbose=0, warm_start=False))])

# %% [markdown]
# ## Check model is working!

# %%
from sklearn.metrics import roc_curve, auc

y_score = model.predict_proba(df_test)[:,1]
fpr, tpr, _ = roc_curve(y_test,y_score)
roc_auc= auc(fpr, tpr)
print("roc_auc",roc_auc)

assert roc_auc>=.85,"something is wrong, check that score, auc<.8"
# Out:
# roc_auc 0.8972048306942328

# %% [markdown]
# # Calculate Shapley values

# %% [markdown]
# ## Get transformed feature values/matrix

# %%
import sklearn
from copy import deepcopy

# Split pipeline & classifier, allowing Shap to use fast tree method
# *Work in progress* - could we bypass this? Let me know!

model_prep=deepcopy(model)
model_clf=model_prep.steps.pop()[1]

# Using 100 rows, just for quick testing
# more rows add more detail to shap explanations
SAMPLE_ROWS=100

df_explanation=df_test.sample(SAMPLE_ROWS)

# Get transformed set from raw data (shap will need it instead of raw data)
X_explanation_rows=model_prep.transform(df_explanation)
X_explanation_rows
# Out:
#         Age  Final Weight  Education-Num  Capital Gain  Capital Loss  \
# 3862   43.0      175133.0           10.0           0.0           0.0
# 5769   43.0      157473.0            9.0           0.0           0.0
# 1251   21.0      197583.0           10.0           0.0           0.0
# 2321   35.0      403489.0            9.0           0.0           0.0
# 11543  57.0      256630.0           13.0           0.0           0.0
# 4288   25.0      150312.0            9.0           0.0           0.0
# 3704   43.0       72338.0           14.0           0.0           0.0
# 13347  25.0      108838.0           13.0           0.0           0.0
# 3450   53.0      185283.0            9.0           0.0           0.0
# 398    36.0      116358.0           14.0           0.0           0.0
# 6500   36.0       65382.0            9.0           0.0           0.0
# 8060   34.0      127875.0           13.0           0.0           0.0
# 5293   30.0      136331.0            9.0           0.0           0.0
# 8164   47.0      275163.0            9.0           0.0           0.0
# 15521  42.0       34722.0            9.0           0.0           0.0
# 1161   38.0      258339.0           11.0           0.0           0.0
# 14700  24.0      231261.0            8.0           0.0           0.0
# 607    32.0      267859.0           10.0           0.0           0.0
# 3228   34.0       73296.0            7.0           0.0           0.0
# 10133  47.0      183186.0           13.0           0.0           0.0
# 11872  30.0      325658.0            9.0           0.0           0.0
# 920    45.0      167159.0           13.0           0.0           0.0
# 4785   37.0      207066.0           14.0           0.0           0.0
# 7147   26.0      272865.0            9.0           0.0           0.0
# 15927  24.0      362059.0            8.0           0.0           0.0
# 2196   25.0      179255.0           10.0           0.0           0.0
# 992    59.0       77816.0           15.0       99999.0           0.0
# 2174   17.0      138507.0            6.0           0.0           0.0
# 4319   39.0      245361.0           10.0           0.0           0.0
# 11919  50.0       69477.0            6.0           0.0           0.0
# ...     ...           ...            ...           ...           ...
# 8232   64.0      198466.0            9.0           0.0           0.0
# 5238   63.0      210350.0            3.0           0.0           0.0
# 4130   50.0      240374.0           14.0           0.0           0.0
# 1517   69.0      199829.0           13.0           0.0        1258.0
# 4911   19.0     1047822.0            7.0           0.0           0.0
# 6120   26.0      331861.0           13.0           0.0           0.0
# 10224  54.0      283725.0           14.0           0.0           0.0
# 3475   53.0      108435.0            9.0           0.0           0.0
# 6585   32.0      262092.0           13.0        7298.0           0.0
# 7266   51.0      156877.0            5.0           0.0           0.0
# 4805   43.0      183342.0           13.0           0.0           0.0
# 10640  30.0      177675.0            9.0           0.0           0.0
# 5672   17.0      165018.0            6.0           0.0           0.0
# 6880   52.0      236222.0            9.0           0.0           0.0
# 1603   45.0      180010.0            9.0           0.0           0.0
# 5310   43.0      183608.0            9.0           0.0           0.0
# 12257  30.0      247328.0           11.0           0.0           0.0
# 13219  28.0      105422.0           10.0           0.0           0.0
# 3792   49.0      186256.0           10.0           0.0           0.0
# 5224   48.0      443377.0           14.0           0.0           0.0
# 10941  24.0       61791.0            5.0           0.0           0.0
# 13564  34.0       49539.0            9.0           0.0           0.0
# 6223   53.0      168723.0           12.0           0.0           0.0
# 2578   24.0      236601.0           10.0           0.0        2339.0
# 5596   39.0      112077.0            9.0           0.0           0.0
# 13493  38.0      191455.0            9.0           0.0           0.0
# 8861   44.0      320451.0           13.0       15024.0           0.0
# 11958  41.0      103614.0           13.0           0.0           0.0
# 6682   25.0      335522.0            5.0           0.0           0.0
# 9231   34.0      150154.0            9.0           0.0           0.0
#
#        Hours per week  Workclass_ ?  Workclass_ Federal-gov  \
# 3862             35.0           0.0                     0.0
# 5769             40.0           0.0                     0.0
# 1251             40.0           1.0                     0.0
# 2321             40.0           0.0                     1.0
# 11543            60.0           0.0                     0.0
# 4288             40.0           0.0                     0.0
# 3704             40.0           0.0                     0.0
# 13347            40.0           0.0                     0.0
# 3450             45.0           0.0                     0.0
# 398              45.0           0.0                     0.0
# 6500             50.0           0.0                     0.0
# 8060             20.0           0.0                     0.0
# 5293             40.0           0.0                     0.0
# 8164             45.0           0.0                     0.0
# 15521            60.0           0.0                     0.0
# 1161             70.0           0.0                     0.0
# 14700            50.0           0.0                     0.0
# 607              50.0           0.0                     0.0
# 3228             40.0           1.0                     0.0
# 10133            60.0           0.0                     0.0
# 11872            40.0           0.0                     0.0
# 920              40.0           0.0                     0.0
# 4785             70.0           0.0                     0.0
# 7147             40.0           0.0                     0.0
# 15927            32.0           0.0                     0.0
# 2196             25.0           0.0                     0.0
# 992              40.0           0.0                     0.0
# 2174             12.0           0.0                     0.0
# 4319             10.0           0.0                     0.0
# 11919            45.0           0.0                     0.0
# ...               ...           ...                     ...
# 8232             70.0           0.0                     0.0
# 5238             32.0           0.0                     0.0
# 4130             50.0           0.0                     0.0
# 1517             40.0           0.0                     0.0
# 4911             25.0           0.0                     0.0
# 6120             50.0           0.0                     0.0
# 10224            40.0           0.0                     0.0
# 3475             40.0           0.0                     0.0
# 6585             50.0           0.0                     0.0
# 7266             60.0           1.0                     0.0
# 4805             40.0           0.0                     0.0
# 10640            40.0           0.0                     0.0
# 5672             10.0           0.0                     0.0
# 6880             40.0           0.0                     0.0
# 1603             40.0           0.0                     0.0
# 5310             40.0           0.0                     1.0
# 12257            40.0           0.0                     0.0
# 13219            50.0           0.0                     0.0
# 3792             40.0           0.0                     0.0
# 5224             60.0           0.0                     0.0
# 10941            40.0           1.0                     0.0
# 13564            20.0           0.0                     0.0
# 6223             40.0           0.0                     0.0
# 2578             43.0           0.0                     0.0
# 5596             40.0           0.0                     0.0
# 13493            10.0           0.0                     0.0
# 8861             40.0           0.0                     1.0
# 11958            45.0           0.0                     0.0
# 6682             40.0           0.0                     0.0
# 9231             50.0           0.0                     0.0
#
#        Workclass_ Local-gov  Workclass_ Never-worked         ...           \
# 3862                    0.0                      0.0         ...
# 5769                    0.0                      0.0         ...
# 1251                    0.0                      0.0         ...
# 2321                    0.0                      0.0         ...
# 11543                   0.0                      0.0         ...
# 4288                    0.0                      0.0         ...
# 3704                    0.0                      0.0         ...
# 13347                   0.0                      0.0         ...
# 3450                    0.0                      0.0         ...
# 398                     0.0                      0.0         ...
# 6500                    0.0                      0.0         ...
# 8060                    0.0                      0.0         ...
# 5293                    0.0                      0.0         ...
# 8164                    0.0                      0.0         ...
# 15521                   0.0                      0.0         ...
# 1161                    0.0                      0.0         ...
# 14700                   0.0                      0.0         ...
# 607                     1.0                      0.0         ...
# 3228                    0.0                      0.0         ...
# 10133                   0.0                      0.0         ...
# 11872                   1.0                      0.0         ...
# 920                     0.0                      0.0         ...
# 4785                    0.0                      0.0         ...
# 7147                    0.0                      0.0         ...
# 15927                   0.0                      0.0         ...
# 2196                    0.0                      0.0         ...
# 992                     0.0                      0.0         ...
# 2174                    0.0                      0.0         ...
# 4319                    0.0                      0.0         ...
# 11919                   0.0                      0.0         ...
# ...                     ...                      ...         ...
# 8232                    0.0                      0.0         ...
# 5238                    0.0                      0.0         ...
# 4130                    0.0                      0.0         ...
# 1517                    0.0                      0.0         ...
# 4911                    0.0                      0.0         ...
# 6120                    0.0                      0.0         ...
# 10224                   0.0                      0.0         ...
# 3475                    0.0                      0.0         ...
# 6585                    0.0                      0.0         ...
# 7266                    0.0                      0.0         ...
# 4805                    0.0                      0.0         ...
# 10640                   0.0                      0.0         ...
# 5672                    0.0                      0.0         ...
# 6880                    0.0                      0.0         ...
# 1603                    0.0                      0.0         ...
# 5310                    0.0                      0.0         ...
# 12257                   0.0                      0.0         ...
# 13219                   0.0                      0.0         ...
# 3792                    0.0                      0.0         ...
# 5224                    0.0                      0.0         ...
# 10941                   0.0                      0.0         ...
# 13564                   0.0                      0.0         ...
# 6223                    0.0                      0.0         ...
# 2578                    0.0                      0.0         ...
# 5596                    0.0                      0.0         ...
# 13493                   0.0                      0.0         ...
# 8861                    0.0                      0.0         ...
# 11958                   1.0                      0.0         ...
# 6682                    0.0                      0.0         ...
# 9231                    0.0                      0.0         ...
#
#        Country_ Portugal  Country_ Puerto-Rico  Country_ Scotland  \
# 3862                 0.0                   0.0                0.0
# 5769                 0.0                   0.0                0.0
# 1251                 0.0                   0.0                0.0
# 2321                 0.0                   0.0                0.0
# 11543                0.0                   0.0                0.0
# 4288                 0.0                   0.0                0.0
# 3704                 0.0                   0.0                0.0
# 13347                0.0                   0.0                0.0
# 3450                 0.0                   0.0                0.0
# 398                  0.0                   0.0                0.0
# 6500                 0.0                   0.0                0.0
# 8060                 0.0                   0.0                0.0
# 5293                 0.0                   0.0                0.0
# 8164                 0.0                   0.0                0.0
# 15521                0.0                   0.0                0.0
# 1161                 0.0                   0.0                0.0
# 14700                0.0                   0.0                0.0
# 607                  0.0                   0.0                0.0
# 3228                 0.0                   0.0                0.0
# 10133                0.0                   0.0                0.0
# 11872                0.0                   0.0                0.0
# 920                  0.0                   0.0                0.0
# 4785                 0.0                   0.0                0.0
# 7147                 0.0                   0.0                0.0
# 15927                0.0                   0.0                0.0
# 2196                 0.0                   0.0                0.0
# 992                  0.0                   0.0                0.0
# 2174                 0.0                   0.0                0.0
# 4319                 0.0                   0.0                0.0
# 11919                0.0                   0.0                0.0
# ...                  ...                   ...                ...
# 8232                 0.0                   0.0                0.0
# 5238                 0.0                   0.0                0.0
# 4130                 0.0                   0.0                0.0
# 1517                 0.0                   0.0                0.0
# 4911                 0.0                   0.0                0.0
# 6120                 0.0                   0.0                0.0
# 10224                0.0                   0.0                0.0
# 3475                 0.0                   0.0                0.0
# 6585                 0.0                   0.0                0.0
# 7266                 0.0                   0.0                0.0
# 4805                 0.0                   0.0                0.0
# 10640                0.0                   0.0                0.0
# 5672                 0.0                   0.0                0.0
# 6880                 0.0                   0.0                0.0
# 1603                 0.0                   0.0                0.0
# 5310                 0.0                   0.0                0.0
# 12257                0.0                   0.0                0.0
# 13219                0.0                   0.0                0.0
# 3792                 0.0                   0.0                0.0
# 5224                 0.0                   0.0                0.0
# 10941                0.0                   0.0                0.0
# 13564                0.0                   0.0                0.0
# 6223                 0.0                   0.0                0.0
# 2578                 0.0                   0.0                0.0
# 5596                 0.0                   0.0                0.0
# 13493                0.0                   0.0                0.0
# 8861                 0.0                   0.0                0.0
# 11958                0.0                   0.0                0.0
# 6682                 0.0                   0.0                0.0
# 9231                 0.0                   0.0                0.0
#
#        Country_ South  Country_ Taiwan  Country_ Thailand  \
# 3862              0.0              0.0                0.0
# 5769              0.0              0.0                0.0
# 1251              0.0              0.0                0.0
# 2321              0.0              0.0                0.0
# 11543             0.0              0.0                0.0
# 4288              0.0              0.0                0.0
# 3704              0.0              0.0                0.0
# 13347             0.0              0.0                0.0
# 3450              0.0              0.0                0.0
# 398               0.0              0.0                0.0
# 6500              0.0              0.0                0.0
# 8060              0.0              0.0                0.0
# 5293              0.0              0.0                0.0
# 8164              0.0              0.0                0.0
# 15521             0.0              0.0                0.0
# 1161              0.0              0.0                0.0
# 14700             0.0              0.0                0.0
# 607               0.0              0.0                0.0
# 3228              0.0              0.0                0.0
# 10133             0.0              0.0                0.0
# 11872             0.0              0.0                0.0
# 920               0.0              0.0                0.0
# 4785              0.0              0.0                0.0
# 7147              0.0              0.0                0.0
# 15927             0.0              0.0                0.0
# 2196              0.0              0.0                0.0
# 992               0.0              0.0                0.0
# 2174              0.0              0.0                0.0
# 4319              0.0              0.0                0.0
# 11919             0.0              0.0                0.0
# ...               ...              ...                ...
# 8232              0.0              0.0                0.0
# 5238              0.0              0.0                0.0
# 4130              0.0              0.0                0.0
# 1517              0.0              0.0                0.0
# 4911              0.0              0.0                0.0
# 6120              0.0              0.0                0.0
# 10224             0.0              0.0                0.0
# 3475              0.0              0.0                0.0
# 6585              0.0              0.0                0.0
# 7266              0.0              0.0                0.0
# 4805              0.0              0.0                0.0
# 10640             0.0              0.0                0.0
# 5672              0.0              0.0                0.0
# 6880              0.0              0.0                0.0
# 1603              0.0              0.0                0.0
# 5310              0.0              0.0                0.0
# 12257             0.0              0.0                0.0
# 13219             0.0              0.0                0.0
# 3792              0.0              0.0                0.0
# 5224              0.0              0.0                0.0
# 10941             0.0              0.0                0.0
# 13564             0.0              0.0                0.0
# 6223              0.0              0.0                0.0
# 2578              0.0              0.0                0.0
# 5596              0.0              0.0                0.0
# 13493             0.0              0.0                0.0
# 8861              0.0              0.0                0.0
# 11958             0.0              0.0                0.0
# 6682              0.0              0.0                0.0
# 9231              0.0              0.0                0.0
#
#        Country_ Trinadad&Tobago  Country_ United-States  Country_ Vietnam  \
# 3862                        0.0                     1.0               0.0
# 5769                        0.0                     1.0               0.0
# 1251                        0.0                     1.0               0.0
# 2321                        0.0                     1.0               0.0
# 11543                       0.0                     0.0               0.0
# 4288                        0.0                     1.0               0.0
# 3704                        0.0                     1.0               0.0
# 13347                       0.0                     1.0               0.0
# 3450                        0.0                     1.0               0.0
# 398                         0.0                     0.0               0.0
# 6500                        0.0                     1.0               0.0
# 8060                        0.0                     1.0               0.0
# 5293                        0.0                     1.0               0.0
# 8164                        0.0                     1.0               0.0
# 15521                       0.0                     1.0               0.0
# 1161                        0.0                     0.0               0.0
# 14700                       0.0                     1.0               0.0
# 607                         0.0                     0.0               0.0
# 3228                        0.0                     1.0               0.0
# 10133                       0.0                     1.0               0.0
# 11872                       0.0                     1.0               0.0
# 920                         0.0                     1.0               0.0
# 4785                        0.0                     1.0               0.0
# 7147                        0.0                     1.0               0.0
# 15927                       0.0                     1.0               0.0
# 2196                        0.0                     1.0               0.0
# 992                         0.0                     1.0               0.0
# 2174                        0.0                     1.0               0.0
# 4319                        0.0                     1.0               0.0
# 11919                       0.0                     1.0               0.0
# ...                         ...                     ...               ...
# 8232                        0.0                     1.0               0.0
# 5238                        0.0                     0.0               0.0
# 4130                        0.0                     1.0               0.0
# 1517                        0.0                     1.0               0.0
# 4911                        0.0                     1.0               0.0
# 6120                        0.0                     0.0               0.0
# 10224                       0.0                     1.0               0.0
# 3475                        0.0                     0.0               0.0
# 6585                        0.0                     1.0               0.0
# 7266                        0.0                     1.0               0.0
# 4805                        0.0                     1.0               0.0
# 10640                       0.0                     1.0               0.0
# 5672                        0.0                     1.0               0.0
# 6880                        0.0                     1.0               0.0
# 1603                        0.0                     1.0               0.0
# 5310                        0.0                     1.0               0.0
# 12257                       0.0                     0.0               0.0
# 13219                       0.0                     1.0               0.0
# 3792                        0.0                     1.0               0.0
# 5224                        0.0                     1.0               0.0
# 10941                       0.0                     1.0               0.0
# 13564                       0.0                     1.0               0.0
# 6223                        0.0                     1.0               0.0
# 2578                        0.0                     1.0               0.0
# 5596                        0.0                     1.0               0.0
# 13493                       0.0                     1.0               0.0
# 8861                        0.0                     0.0               0.0
# 11958                       0.0                     1.0               0.0
# 6682                        0.0                     0.0               0.0
# 9231                        0.0                     1.0               0.0
#
#        Country_ Yugoslavia
# 3862                   0.0
# 5769                   0.0
# 1251                   0.0
# 2321                   0.0
# 11543                  0.0
# 4288                   0.0
# 3704                   0.0
# 13347                  0.0
# 3450                   0.0
# 398                    0.0
# 6500                   0.0
# 8060                   0.0
# 5293                   0.0
# 8164                   0.0
# 15521                  0.0
# 1161                   0.0
# 14700                  0.0
# 607                    0.0
# 3228                   0.0
# 10133                  0.0
# 11872                  0.0
# 920                    0.0
# 4785                   0.0
# 7147                   0.0
# 15927                  0.0
# 2196                   0.0
# 992                    0.0
# 2174                   0.0
# 4319                   0.0
# 11919                  0.0
# ...                    ...
# 8232                   0.0
# 5238                   0.0
# 4130                   0.0
# 1517                   0.0
# 4911                   0.0
# 6120                   0.0
# 10224                  0.0
# 3475                   0.0
# 6585                   0.0
# 7266                   0.0
# 4805                   0.0
# 10640                  0.0
# 5672                   0.0
# 6880                   0.0
# 1603                   0.0
# 5310                   0.0
# 12257                  0.0
# 13219                  0.0
# 3792                   0.0
# 5224                   0.0
# 10941                  0.0
# 13564                  0.0
# 6223                   0.0
# 2578                   0.0
# 5596                   0.0
# 13493                  0.0
# 8861                   0.0
# 11958                  0.0
# 6682                   0.0
# 9231                   0.0
#
# [100 rows x 107 columns]

# %%
import shap

feature_names=X_explanation_rows.columns.values

# use fast shapley tree explainer
shap_explainer=shap.TreeExplainer(model_clf)
shap_values = shap_explainer.shap_values(X_explanation_rows)

# Use [1] (true label is in index 1, get that)
shap_values=shap_values[1]

# can take a while depending on cores/proc speed
# 100 rows on i5 laptop, for this dataset, ~ 10 secs

# %% [markdown]
# # Data prep for explanations & Dash

# %%
# Some columns that help on table sorting, filtering, etc

df_explanation["SCORE_PROB"]=model_clf.predict_proba(X_explanation_rows)[:,1]

# Use baseline probability from shap_explainer to create ratio to base rate
df_explanation["SCORE_RATIO"]=df_explanation.SCORE_PROB/shap_explainer.expected_value[1]

# Just because...
df_explanation[["SCORE_PROB","SCORE_RATIO"]]=df_explanation[["SCORE_PROB","SCORE_RATIO"]].round(2)
df_explanation
# Out:
#        Age          Workclass  Final Weight      Education  Education-Num  \
# 3862    43            Private        175133   Some-college             10
# 5769    43            Private        157473        HS-grad              9
# 1251    21                  ?        197583   Some-college             10
# 2321    35        Federal-gov        403489        HS-grad              9
# 11543   57   Self-emp-not-inc        256630      Bachelors             13
# 4288    25            Private        150312        HS-grad              9
# 3704    43            Private         72338        Masters             14
# 13347   25            Private        108838      Bachelors             13
# 3450    53            Private        185283        HS-grad              9
# 398     36            Private        116358        Masters             14
# 6500    36            Private         65382        HS-grad              9
# 8060    34            Private        127875      Bachelors             13
# 5293    30            Private        136331        HS-grad              9
# 8164    47            Private        275163        HS-grad              9
# 15521   42   Self-emp-not-inc         34722        HS-grad              9
# 1161    38            Private        258339      Assoc-voc             11
# 14700   24            Private        231261           12th              8
# 607     32          Local-gov        267859   Some-college             10
# 3228    34                  ?         73296           11th              7
# 10133   47            Private        183186      Bachelors             13
# 11872   30          Local-gov        325658        HS-grad              9
# 920     45            Private        167159      Bachelors             13
# 4785    37            Private        207066        Masters             14
# 7147    26            Private        272865        HS-grad              9
# 15927   24            Private        362059           12th              8
# 2196    25            Private        179255   Some-college             10
# 992     59       Self-emp-inc         77816    Prof-school             15
# 2174    17            Private        138507           10th              6
# 4319    39   Self-emp-not-inc        245361   Some-college             10
# 11919   50            Private         69477           10th              6
# ...    ...                ...           ...            ...            ...
# 8232    64   Self-emp-not-inc        198466        HS-grad              9
# 5238    63            Private        210350        5th-6th              3
# 4130    50            Private        240374        Masters             14
# 1517    69   Self-emp-not-inc        199829      Bachelors             13
# 4911    19            Private       1047822           11th              7
# 6120    26            Private        331861      Bachelors             13
# 10224   54            Private        283725        Masters             14
# 3475    53            Private        108435        HS-grad              9
# 6585    32            Private        262092      Bachelors             13
# 7266    51                  ?        156877            9th              5
# 4805    43            Private        183342      Bachelors             13
# 10640   30            Private        177675        HS-grad              9
# 5672    17            Private        165018           10th              6
# 6880    52            Private        236222        HS-grad              9
# 1603    45            Private        180010        HS-grad              9
# 5310    43        Federal-gov        183608        HS-grad              9
# 12257   30   Self-emp-not-inc        247328      Assoc-voc             11
# 13219   28            Private        105422   Some-college             10
# 3792    49            Private        186256   Some-college             10
# 5224    48            Private        443377        Masters             14
# 10941   24                  ?         61791            9th              5
# 13564   34          State-gov         49539        HS-grad              9
# 6223    53            Private        168723     Assoc-acdm             12
# 2578    24            Private        236601   Some-college             10
# 5596    39            Private        112077        HS-grad              9
# 13493   38            Private        191455        HS-grad              9
# 8861    44        Federal-gov        320451      Bachelors             13
# 11958   41          Local-gov        103614      Bachelors             13
# 6682    25            Private        335522            9th              5
# 9231    34            Private        150154        HS-grad              9
#
#             Marital Status          Occupation     Relationship  \
# 3862              Divorced        Tech-support        Unmarried
# 5769         Never-married               Sales    Not-in-family
# 1251         Never-married                   ?        Own-child
# 2321         Never-married        Adm-clerical        Own-child
# 11543             Divorced               Sales    Not-in-family
# 4288         Never-married   Machine-op-inspct    Not-in-family
# 3704    Married-civ-spouse        Tech-support          Husband
# 13347        Never-married        Adm-clerical    Not-in-family
# 3450    Married-civ-spouse        Craft-repair          Husband
# 398     Married-civ-spouse     Exec-managerial          Husband
# 6500    Married-civ-spouse        Craft-repair          Husband
# 8060         Never-married        Adm-clerical    Not-in-family
# 5293    Married-civ-spouse        Adm-clerical          Husband
# 8164    Married-civ-spouse        Craft-repair          Husband
# 15521   Married-civ-spouse               Sales          Husband
# 1161    Married-civ-spouse       Other-service          Husband
# 14700   Married-civ-spouse        Adm-clerical          Husband
# 607     Married-civ-spouse     Protective-serv          Husband
# 3228         Never-married                   ?    Not-in-family
# 10133   Married-civ-spouse     Exec-managerial          Husband
# 11872   Married-civ-spouse     Exec-managerial          Husband
# 920     Married-civ-spouse        Craft-repair          Husband
# 4785    Married-civ-spouse      Prof-specialty          Husband
# 7147    Married-civ-spouse        Craft-repair          Husband
# 15927        Never-married        Craft-repair        Own-child
# 2196         Never-married        Adm-clerical        Own-child
# 992     Married-civ-spouse      Prof-specialty          Husband
# 2174         Never-married   Handlers-cleaners        Own-child
# 4319         Never-married      Prof-specialty        Own-child
# 11919   Married-civ-spouse     Farming-fishing          Husband
# ...                    ...                 ...              ...
# 8232               Widowed               Sales    Not-in-family
# 5238    Married-civ-spouse   Machine-op-inspct          Husband
# 4130    Married-civ-spouse     Exec-managerial          Husband
# 1517    Married-civ-spouse     Exec-managerial          Husband
# 4911         Never-married               Sales        Unmarried
# 6120         Never-married        Craft-repair    Not-in-family
# 10224             Divorced               Sales    Not-in-family
# 3475    Married-civ-spouse        Tech-support          Husband
# 6585    Married-civ-spouse      Prof-specialty          Husband
# 7266             Separated                   ?    Not-in-family
# 4805    Married-civ-spouse        Adm-clerical          Husband
# 10640        Never-married   Machine-op-inspct   Other-relative
# 5672         Never-married               Sales        Own-child
# 6880              Divorced     Exec-managerial    Not-in-family
# 1603              Divorced               Sales        Own-child
# 5310              Divorced        Adm-clerical    Not-in-family
# 12257            Separated               Sales    Not-in-family
# 13219        Never-married    Transport-moving    Not-in-family
# 3792    Married-civ-spouse        Adm-clerical          Husband
# 5224         Never-married      Prof-specialty    Not-in-family
# 10941   Married-civ-spouse                   ?             Wife
# 13564        Never-married       Other-service        Own-child
# 6223    Married-civ-spouse        Tech-support          Husband
# 2578              Divorced   Machine-op-inspct    Not-in-family
# 5596    Married-civ-spouse        Craft-repair          Husband
# 13493   Married-civ-spouse       Other-service             Wife
# 8861    Married-civ-spouse      Prof-specialty          Husband
# 11958   Married-civ-spouse      Prof-specialty          Husband
# 6682         Never-married   Handlers-cleaners    Not-in-family
# 9231    Married-civ-spouse        Craft-repair          Husband
#
#                       Race      Sex  Capital Gain  Capital Loss  \
# 3862                 Black   Female             0             0
# 5769                 White   Female             0             0
# 1251                 White   Female             0             0
# 2321                 White     Male             0             0
# 11543                White     Male             0             0
# 4288                 White     Male             0             0
# 3704    Asian-Pac-Islander     Male             0             0
# 13347                White   Female             0             0
# 3450                 White     Male             0             0
# 398     Asian-Pac-Islander     Male             0             0
# 6500                 White     Male             0             0
# 8060                 White   Female             0             0
# 5293                 White     Male             0             0
# 8164                 White     Male             0             0
# 15521                White     Male             0             0
# 1161                 White     Male             0             0
# 14700                White     Male             0             0
# 607                  White     Male             0             0
# 3228                 Black   Female             0             0
# 10133                White     Male             0             0
# 11872                White     Male             0             0
# 920                  White     Male             0             0
# 4785                 White     Male             0             0
# 7147                 White     Male             0             0
# 15927                White     Male             0             0
# 2196                 White   Female             0             0
# 992                  White     Male         99999             0
# 2174                 White     Male             0             0
# 4319                 White   Female             0             0
# 11919                White     Male             0             0
# ...                    ...      ...           ...           ...
# 8232                 White   Female             0             0
# 5238                 Other     Male             0             0
# 4130                 White     Male             0             0
# 1517                 White     Male             0          1258
# 4911                 White   Female             0             0
# 6120                 White     Male             0             0
# 10224                White   Female             0             0
# 3475                 White     Male             0             0
# 6585                 White     Male          7298             0
# 7266                 White     Male             0             0
# 4805                 White     Male             0             0
# 10640                White     Male             0             0
# 5672                 White   Female             0             0
# 6880                 White   Female             0             0
# 1603                 White   Female             0             0
# 5310                 Black   Female             0             0
# 12257                White     Male             0             0
# 13219                White     Male             0             0
# 3792                 White     Male             0             0
# 5224                 White     Male             0             0
# 10941                White   Female             0             0
# 13564                White   Female             0             0
# 6223                 White     Male             0             0
# 2578                 White     Male             0          2339
# 5596                 White     Male             0             0
# 13493                White   Female             0             0
# 8861    Asian-Pac-Islander     Male         15024             0
# 11958                White     Male             0             0
# 6682                 White     Male             0             0
# 9231                 White     Male             0             0
#
#        Hours per week         Country   Income  SCORE_PROB  SCORE_RATIO
# 3862               35   United-States   <=50K.        0.18         0.36
# 5769               40   United-States   <=50K.        0.18         0.36
# 1251               40   United-States   <=50K.        0.07         0.13
# 2321               40   United-States   <=50K.        0.15         0.31
# 11543              60          Canada    >50K.        0.47         0.95
# 4288               40   United-States   <=50K.        0.13         0.25
# 3704               40   United-States    >50K.        0.74         1.48
# 13347              40   United-States   <=50K.        0.21         0.42
# 3450               45   United-States    >50K.        0.61         1.23
# 398                45           India   <=50K.        0.80         1.60
# 6500               50   United-States   <=50K.        0.61         1.22
# 8060               20   United-States   <=50K.        0.28         0.57
# 5293               40   United-States   <=50K.        0.57         1.15
# 8164               45   United-States   <=50K.        0.61         1.23
# 15521              60   United-States   <=50K.        0.62         1.23
# 1161               70            Iran   <=50K.        0.58         1.16
# 14700              50   United-States   <=50K.        0.52         1.04
# 607                50            Cuba   <=50K.        0.65         1.30
# 3228               40   United-States   <=50K.        0.15         0.30
# 10133              60   United-States    >50K.        0.81         1.61
# 11872              40   United-States   <=50K.        0.64         1.28
# 920                40   United-States   <=50K.        0.73         1.46
# 4785               70   United-States   <=50K.        0.80         1.60
# 7147               40   United-States   <=50K.        0.48         0.96
# 15927              32   United-States   <=50K.        0.08         0.16
# 2196               25   United-States   <=50K.        0.07         0.13
# 992                40   United-States    >50K.        0.88         1.75
# 2174               12   United-States   <=50K.        0.06         0.12
# 4319               10   United-States   <=50K.        0.19         0.38
# 11919              45   United-States   <=50K.        0.55         1.09
# ...               ...             ...      ...         ...          ...
# 8232               70   United-States   <=50K.        0.29         0.58
# 5238               32          Mexico   <=50K.        0.43         0.86
# 4130               50   United-States    >50K.        0.82         1.65
# 1517               40   United-States   <=50K.        0.77         1.54
# 4911               25   United-States   <=50K.        0.10         0.19
# 6120               50         England   <=50K.        0.31         0.61
# 10224              40   United-States   <=50K.        0.40         0.80
# 3475               40           Italy   <=50K.        0.60         1.20
# 6585               50   United-States    >50K.        0.87         1.73
# 7266               60   United-States   <=50K.        0.28         0.57
# 4805               40   United-States    >50K.        0.73         1.46
# 10640              40   United-States   <=50K.        0.18         0.36
# 5672               10   United-States   <=50K.        0.06         0.12
# 6880               40   United-States   <=50K.        0.28         0.56
# 1603               40   United-States   <=50K.        0.18         0.37
# 5310               40   United-States   <=50K.        0.20         0.39
# 12257              40          Mexico   <=50K.        0.27         0.54
# 13219              50   United-States   <=50K.        0.26         0.51
# 3792               40   United-States   <=50K.        0.62         1.25
# 5224               60   United-States   <=50K.        0.50         1.00
# 10941              40   United-States   <=50K.        0.41         0.81
# 13564              20   United-States   <=50K.        0.09         0.19
# 6223               40   United-States    >50K.        0.64         1.28
# 2578               43   United-States   <=50K.        0.32         0.64
# 5596               40   United-States   <=50K.        0.59         1.17
# 13493              10   United-States   <=50K.        0.45         0.89
# 8861               40     Philippines    >50K.        0.85         1.70
# 11958              45   United-States    >50K.        0.79         1.57
# 6682               40          Mexico   <=50K.        0.11         0.23
# 9231               50   United-States    >50K.        0.61         1.21
#
# [100 rows x 17 columns]

# %%
# Cast calculated shap values as dataframe, to use index based getters later on
df_shap_values=pd.DataFrame(shap_values,columns=feature_names)
df_shap_values.index=X_explanation_rows.index

# Add top N positive/negative features to each row (this allows table search, which is cool) 
N=5

topN=df_shap_values.apply(lambda s: ",".join(s.nlargest(N).index.tolist()), axis=1)
bottomN=df_shap_values.apply(lambda s: ",".join(s.nsmallest(N).index.tolist()), axis=1)

df_explanation["TOP_POS"]=topN.values
df_explanation["TOP_NEG"]=bottomN.values

df_explanation
# Out:
#        Age          Workclass  Final Weight      Education  Education-Num  \
# 3862    43            Private        175133   Some-college             10
# 5769    43            Private        157473        HS-grad              9
# 1251    21                  ?        197583   Some-college             10
# 2321    35        Federal-gov        403489        HS-grad              9
# 11543   57   Self-emp-not-inc        256630      Bachelors             13
# 4288    25            Private        150312        HS-grad              9
# 3704    43            Private         72338        Masters             14
# 13347   25            Private        108838      Bachelors             13
# 3450    53            Private        185283        HS-grad              9
# 398     36            Private        116358        Masters             14
# 6500    36            Private         65382        HS-grad              9
# 8060    34            Private        127875      Bachelors             13
# 5293    30            Private        136331        HS-grad              9
# 8164    47            Private        275163        HS-grad              9
# 15521   42   Self-emp-not-inc         34722        HS-grad              9
# 1161    38            Private        258339      Assoc-voc             11
# 14700   24            Private        231261           12th              8
# 607     32          Local-gov        267859   Some-college             10
# 3228    34                  ?         73296           11th              7
# 10133   47            Private        183186      Bachelors             13
# 11872   30          Local-gov        325658        HS-grad              9
# 920     45            Private        167159      Bachelors             13
# 4785    37            Private        207066        Masters             14
# 7147    26            Private        272865        HS-grad              9
# 15927   24            Private        362059           12th              8
# 2196    25            Private        179255   Some-college             10
# 992     59       Self-emp-inc         77816    Prof-school             15
# 2174    17            Private        138507           10th              6
# 4319    39   Self-emp-not-inc        245361   Some-college             10
# 11919   50            Private         69477           10th              6
# ...    ...                ...           ...            ...            ...
# 8232    64   Self-emp-not-inc        198466        HS-grad              9
# 5238    63            Private        210350        5th-6th              3
# 4130    50            Private        240374        Masters             14
# 1517    69   Self-emp-not-inc        199829      Bachelors             13
# 4911    19            Private       1047822           11th              7
# 6120    26            Private        331861      Bachelors             13
# 10224   54            Private        283725        Masters             14
# 3475    53            Private        108435        HS-grad              9
# 6585    32            Private        262092      Bachelors             13
# 7266    51                  ?        156877            9th              5
# 4805    43            Private        183342      Bachelors             13
# 10640   30            Private        177675        HS-grad              9
# 5672    17            Private        165018           10th              6
# 6880    52            Private        236222        HS-grad              9
# 1603    45            Private        180010        HS-grad              9
# 5310    43        Federal-gov        183608        HS-grad              9
# 12257   30   Self-emp-not-inc        247328      Assoc-voc             11
# 13219   28            Private        105422   Some-college             10
# 3792    49            Private        186256   Some-college             10
# 5224    48            Private        443377        Masters             14
# 10941   24                  ?         61791            9th              5
# 13564   34          State-gov         49539        HS-grad              9
# 6223    53            Private        168723     Assoc-acdm             12
# 2578    24            Private        236601   Some-college             10
# 5596    39            Private        112077        HS-grad              9
# 13493   38            Private        191455        HS-grad              9
# 8861    44        Federal-gov        320451      Bachelors             13
# 11958   41          Local-gov        103614      Bachelors             13
# 6682    25            Private        335522            9th              5
# 9231    34            Private        150154        HS-grad              9
#
#             Marital Status          Occupation     Relationship  \
# 3862              Divorced        Tech-support        Unmarried
# 5769         Never-married               Sales    Not-in-family
# 1251         Never-married                   ?        Own-child
# 2321         Never-married        Adm-clerical        Own-child
# 11543             Divorced               Sales    Not-in-family
# 4288         Never-married   Machine-op-inspct    Not-in-family
# 3704    Married-civ-spouse        Tech-support          Husband
# 13347        Never-married        Adm-clerical    Not-in-family
# 3450    Married-civ-spouse        Craft-repair          Husband
# 398     Married-civ-spouse     Exec-managerial          Husband
# 6500    Married-civ-spouse        Craft-repair          Husband
# 8060         Never-married        Adm-clerical    Not-in-family
# 5293    Married-civ-spouse        Adm-clerical          Husband
# 8164    Married-civ-spouse        Craft-repair          Husband
# 15521   Married-civ-spouse               Sales          Husband
# 1161    Married-civ-spouse       Other-service          Husband
# 14700   Married-civ-spouse        Adm-clerical          Husband
# 607     Married-civ-spouse     Protective-serv          Husband
# 3228         Never-married                   ?    Not-in-family
# 10133   Married-civ-spouse     Exec-managerial          Husband
# 11872   Married-civ-spouse     Exec-managerial          Husband
# 920     Married-civ-spouse        Craft-repair          Husband
# 4785    Married-civ-spouse      Prof-specialty          Husband
# 7147    Married-civ-spouse        Craft-repair          Husband
# 15927        Never-married        Craft-repair        Own-child
# 2196         Never-married        Adm-clerical        Own-child
# 992     Married-civ-spouse      Prof-specialty          Husband
# 2174         Never-married   Handlers-cleaners        Own-child
# 4319         Never-married      Prof-specialty        Own-child
# 11919   Married-civ-spouse     Farming-fishing          Husband
# ...                    ...                 ...              ...
# 8232               Widowed               Sales    Not-in-family
# 5238    Married-civ-spouse   Machine-op-inspct          Husband
# 4130    Married-civ-spouse     Exec-managerial          Husband
# 1517    Married-civ-spouse     Exec-managerial          Husband
# 4911         Never-married               Sales        Unmarried
# 6120         Never-married        Craft-repair    Not-in-family
# 10224             Divorced               Sales    Not-in-family
# 3475    Married-civ-spouse        Tech-support          Husband
# 6585    Married-civ-spouse      Prof-specialty          Husband
# 7266             Separated                   ?    Not-in-family
# 4805    Married-civ-spouse        Adm-clerical          Husband
# 10640        Never-married   Machine-op-inspct   Other-relative
# 5672         Never-married               Sales        Own-child
# 6880              Divorced     Exec-managerial    Not-in-family
# 1603              Divorced               Sales        Own-child
# 5310              Divorced        Adm-clerical    Not-in-family
# 12257            Separated               Sales    Not-in-family
# 13219        Never-married    Transport-moving    Not-in-family
# 3792    Married-civ-spouse        Adm-clerical          Husband
# 5224         Never-married      Prof-specialty    Not-in-family
# 10941   Married-civ-spouse                   ?             Wife
# 13564        Never-married       Other-service        Own-child
# 6223    Married-civ-spouse        Tech-support          Husband
# 2578              Divorced   Machine-op-inspct    Not-in-family
# 5596    Married-civ-spouse        Craft-repair          Husband
# 13493   Married-civ-spouse       Other-service             Wife
# 8861    Married-civ-spouse      Prof-specialty          Husband
# 11958   Married-civ-spouse      Prof-specialty          Husband
# 6682         Never-married   Handlers-cleaners    Not-in-family
# 9231    Married-civ-spouse        Craft-repair          Husband
#
#                       Race      Sex  Capital Gain  Capital Loss  \
# 3862                 Black   Female             0             0
# 5769                 White   Female             0             0
# 1251                 White   Female             0             0
# 2321                 White     Male             0             0
# 11543                White     Male             0             0
# 4288                 White     Male             0             0
# 3704    Asian-Pac-Islander     Male             0             0
# 13347                White   Female             0             0
# 3450                 White     Male             0             0
# 398     Asian-Pac-Islander     Male             0             0
# 6500                 White     Male             0             0
# 8060                 White   Female             0             0
# 5293                 White     Male             0             0
# 8164                 White     Male             0             0
# 15521                White     Male             0             0
# 1161                 White     Male             0             0
# 14700                White     Male             0             0
# 607                  White     Male             0             0
# 3228                 Black   Female             0             0
# 10133                White     Male             0             0
# 11872                White     Male             0             0
# 920                  White     Male             0             0
# 4785                 White     Male             0             0
# 7147                 White     Male             0             0
# 15927                White     Male             0             0
# 2196                 White   Female             0             0
# 992                  White     Male         99999             0
# 2174                 White     Male             0             0
# 4319                 White   Female             0             0
# 11919                White     Male             0             0
# ...                    ...      ...           ...           ...
# 8232                 White   Female             0             0
# 5238                 Other     Male             0             0
# 4130                 White     Male             0             0
# 1517                 White     Male             0          1258
# 4911                 White   Female             0             0
# 6120                 White     Male             0             0
# 10224                White   Female             0             0
# 3475                 White     Male             0             0
# 6585                 White     Male          7298             0
# 7266                 White     Male             0             0
# 4805                 White     Male             0             0
# 10640                White     Male             0             0
# 5672                 White   Female             0             0
# 6880                 White   Female             0             0
# 1603                 White   Female             0             0
# 5310                 Black   Female             0             0
# 12257                White     Male             0             0
# 13219                White     Male             0             0
# 3792                 White     Male             0             0
# 5224                 White     Male             0             0
# 10941                White   Female             0             0
# 13564                White   Female             0             0
# 6223                 White     Male             0             0
# 2578                 White     Male             0          2339
# 5596                 White     Male             0             0
# 13493                White   Female             0             0
# 8861    Asian-Pac-Islander     Male         15024             0
# 11958                White     Male             0             0
# 6682                 White     Male             0             0
# 9231                 White     Male             0             0
#
#        Hours per week         Country   Income  SCORE_PROB  SCORE_RATIO  \
# 3862               35   United-States   <=50K.        0.18         0.36
# 5769               40   United-States   <=50K.        0.18         0.36
# 1251               40   United-States   <=50K.        0.07         0.13
# 2321               40   United-States   <=50K.        0.15         0.31
# 11543              60          Canada    >50K.        0.47         0.95
# 4288               40   United-States   <=50K.        0.13         0.25
# 3704               40   United-States    >50K.        0.74         1.48
# 13347              40   United-States   <=50K.        0.21         0.42
# 3450               45   United-States    >50K.        0.61         1.23
# 398                45           India   <=50K.        0.80         1.60
# 6500               50   United-States   <=50K.        0.61         1.22
# 8060               20   United-States   <=50K.        0.28         0.57
# 5293               40   United-States   <=50K.        0.57         1.15
# 8164               45   United-States   <=50K.        0.61         1.23
# 15521              60   United-States   <=50K.        0.62         1.23
# 1161               70            Iran   <=50K.        0.58         1.16
# 14700              50   United-States   <=50K.        0.52         1.04
# 607                50            Cuba   <=50K.        0.65         1.30
# 3228               40   United-States   <=50K.        0.15         0.30
# 10133              60   United-States    >50K.        0.81         1.61
# 11872              40   United-States   <=50K.        0.64         1.28
# 920                40   United-States   <=50K.        0.73         1.46
# 4785               70   United-States   <=50K.        0.80         1.60
# 7147               40   United-States   <=50K.        0.48         0.96
# 15927              32   United-States   <=50K.        0.08         0.16
# 2196               25   United-States   <=50K.        0.07         0.13
# 992                40   United-States    >50K.        0.88         1.75
# 2174               12   United-States   <=50K.        0.06         0.12
# 4319               10   United-States   <=50K.        0.19         0.38
# 11919              45   United-States   <=50K.        0.55         1.09
# ...               ...             ...      ...         ...          ...
# 8232               70   United-States   <=50K.        0.29         0.58
# 5238               32          Mexico   <=50K.        0.43         0.86
# 4130               50   United-States    >50K.        0.82         1.65
# 1517               40   United-States   <=50K.        0.77         1.54
# 4911               25   United-States   <=50K.        0.10         0.19
# 6120               50         England   <=50K.        0.31         0.61
# 10224              40   United-States   <=50K.        0.40         0.80
# 3475               40           Italy   <=50K.        0.60         1.20
# 6585               50   United-States    >50K.        0.87         1.73
# 7266               60   United-States   <=50K.        0.28         0.57
# 4805               40   United-States    >50K.        0.73         1.46
# 10640              40   United-States   <=50K.        0.18         0.36
# 5672               10   United-States   <=50K.        0.06         0.12
# 6880               40   United-States   <=50K.        0.28         0.56
# 1603               40   United-States   <=50K.        0.18         0.37
# 5310               40   United-States   <=50K.        0.20         0.39
# 12257              40          Mexico   <=50K.        0.27         0.54
# 13219              50   United-States   <=50K.        0.26         0.51
# 3792               40   United-States   <=50K.        0.62         1.25
# 5224               60   United-States   <=50K.        0.50         1.00
# 10941              40   United-States   <=50K.        0.41         0.81
# 13564              20   United-States   <=50K.        0.09         0.19
# 6223               40   United-States    >50K.        0.64         1.28
# 2578               43   United-States   <=50K.        0.32         0.64
# 5596               40   United-States   <=50K.        0.59         1.17
# 13493              10   United-States   <=50K.        0.45         0.89
# 8861               40     Philippines    >50K.        0.85         1.70
# 11958              45   United-States    >50K.        0.79         1.57
# 6682               40          Mexico   <=50K.        0.11         0.23
# 9231               50   United-States    >50K.        0.61         1.21
#
#                                                  TOP_POS  \
# 3862   Marital Status_ Never-married,Age,Relationship...
# 5769   Age,Relationship_ Own-child,Occupation_ Other-...
# 1251   Education_ HS-grad,Occupation_ Other-service,R...
# 2321   Age,Sex,Workclass_ Federal-gov,Workclass_ Priv...
# 11543  Education-Num,Hours per week,Education_ Bachel...
# 4288   Relationship_ Own-child,Sex,Occupation_ Other-...
# 3704   Marital Status_ Married-civ-spouse,Education-N...
# 13347  Education-Num,Education_ Bachelors,Relationshi...
# 3450   Marital Status_ Married-civ-spouse,Relationshi...
# 398    Education-Num,Marital Status_ Married-civ-spou...
# 6500   Marital Status_ Married-civ-spouse,Relationshi...
# 8060   Education-Num,Education_ Bachelors,Age,Relatio...
# 5293   Marital Status_ Married-civ-spouse,Relationshi...
# 8164   Marital Status_ Married-civ-spouse,Relationshi...
# 15521  Marital Status_ Married-civ-spouse,Relationshi...
# 1161   Marital Status_ Married-civ-spouse,Relationshi...
# 14700  Marital Status_ Married-civ-spouse,Relationshi...
# 607    Marital Status_ Married-civ-spouse,Relationshi...
# 3228   Age,Relationship_ Own-child,Education_ HS-grad...
# 10133  Marital Status_ Married-civ-spouse,Education-N...
# 11872  Marital Status_ Married-civ-spouse,Occupation_...
# 920    Marital Status_ Married-civ-spouse,Education-N...
# 4785   Education-Num,Marital Status_ Married-civ-spou...
# 7147   Marital Status_ Married-civ-spouse,Relationshi...
# 15927  Sex,Education_ HS-grad,Occupation_ Other-servi...
# 2196   Education_ HS-grad,Occupation_ Other-service,R...
# 992    Capital Gain,Education-Num,Marital Status_ Mar...
# 2174   Sex,Education_ HS-grad,Occupation_ Other-servi...
# 4319   Occupation_ Prof-specialty,Age,Education_ HS-g...
# 11919  Marital Status_ Married-civ-spouse,Relationshi...
# ...                                                  ...
# 8232   Hours per week,Marital Status_ Never-married,A...
# 5238   Marital Status_ Married-civ-spouse,Relationshi...
# 4130   Education-Num,Marital Status_ Married-civ-spou...
# 1517   Marital Status_ Married-civ-spouse,Education-N...
# 4911   Relationship_ Own-child,Education_ HS-grad,Occ...
# 6120   Education-Num,Hours per week,Education_ Bachel...
# 10224  Education-Num,Education_ Masters,Marital Statu...
# 3475   Marital Status_ Married-civ-spouse,Relationshi...
# 6585   Capital Gain,Marital Status_ Married-civ-spous...
# 7266   Hours per week,Age,Marital Status_ Never-marri...
# 4805   Marital Status_ Married-civ-spouse,Education-N...
# 10640  Sex,Age,Relationship_ Own-child,Occupation_ Ot...
# 5672   Education_ HS-grad,Occupation_ Other-service,R...
# 6880   Occupation_ Exec-managerial,Marital Status_ Ne...
# 1603   Marital Status_ Never-married,Age,Relationship...
# 5310   Marital Status_ Never-married,Age,Workclass_ F...
# 12257  Marital Status_ Never-married,Sex,Relationship...
# 13219  Hours per week,Sex,Relationship_ Own-child,Edu...
# 3792   Marital Status_ Married-civ-spouse,Relationshi...
# 5224   Education-Num,Education_ Masters,Occupation_ P...
# 10941  Marital Status_ Married-civ-spouse,Relationshi...
# 13564  Age,Workclass_ Private,Relationship_ Unmarried...
# 6223   Marital Status_ Married-civ-spouse,Relationshi...
# 2578   Capital Loss,Hours per week,Marital Status_ Ne...
# 5596   Marital Status_ Married-civ-spouse,Relationshi...
# 13493  Marital Status_ Married-civ-spouse,Relationshi...
# 8861   Capital Gain,Marital Status_ Married-civ-spous...
# 11958  Marital Status_ Married-civ-spouse,Education-N...
# 6682   Relationship_ Own-child,Sex,Education_ HS-grad...
# 9231   Marital Status_ Married-civ-spouse,Relationshi...
#
#                                                  TOP_NEG
# 3862   Marital Status_ Married-civ-spouse,Relationshi...
# 5769   Marital Status_ Married-civ-spouse,Marital Sta...
# 1251   Marital Status_ Married-civ-spouse,Age,Relatio...
# 2321   Marital Status_ Married-civ-spouse,Relationshi...
# 11543  Marital Status_ Married-civ-spouse,Relationshi...
# 4288   Marital Status_ Married-civ-spouse,Age,Marital...
# 3704   Capital Gain,Race_ White,Hours per week,Occupa...
# 13347  Marital Status_ Married-civ-spouse,Age,Marital...
# 3450   Education-Num,Education_ HS-grad,Capital Gain,...
# 398    Capital Gain,Race_ White,Education_ Bachelors,...
# 6500   Education-Num,Education_ HS-grad,Capital Gain,...
# 8060   Marital Status_ Married-civ-spouse,Marital Sta...
# 5293   Education-Num,Education_ HS-grad,Capital Gain,...
# 8164   Education-Num,Education_ HS-grad,Capital Gain,...
# 15521  Education-Num,Education_ HS-grad,Capital Gain,...
# 1161   Occupation_ Other-service,Education-Num,Capita...
# 14700  Age,Education-Num,Capital Gain,Occupation_ Exe...
# 607    Education-Num,Capital Gain,Occupation_ Exec-ma...
# 3228   Marital Status_ Married-civ-spouse,Marital Sta...
# 10133  Capital Gain,Occupation_ Prof-specialty,Educat...
# 11872  Education-Num,Education_ HS-grad,Capital Gain,...
# 920    Capital Gain,Hours per week,Occupation_ Exec-m...
# 4785   Capital Gain,Occupation_ Exec-managerial,Educa...
# 7147   Age,Education-Num,Education_ HS-grad,Capital G...
# 15927  Marital Status_ Married-civ-spouse,Relationshi...
# 2196   Marital Status_ Married-civ-spouse,Relationshi...
# 992    Hours per week,Occupation_ Exec-managerial,Edu...
# 2174   Age,Marital Status_ Married-civ-spouse,Relatio...
# 4319   Marital Status_ Married-civ-spouse,Relationshi...
# 11919  Education-Num,Education_ 10th,Occupation_ Farm...
# ...                                                  ...
# 8232   Marital Status_ Married-civ-spouse,Relationshi...
# 5238   Country_ Mexico,Education-Num,Hours per week,E...
# 4130   Capital Gain,Education_ Bachelors,Occupation_ ...
# 1517   Capital Gain,Hours per week,Occupation_ Prof-s...
# 4911   Marital Status_ Married-civ-spouse,Age,Marital...
# 6120   Age,Marital Status_ Married-civ-spouse,Marital...
# 10224  Marital Status_ Married-civ-spouse,Relationshi...
# 3475   Education-Num,Education_ HS-grad,Capital Gain,...
# 6585   Occupation_ Exec-managerial,Capital Loss,Educa...
# 7266   Marital Status_ Married-civ-spouse,Relationshi...
# 4805   Capital Gain,Hours per week,Occupation_ Adm-cl...
# 10640  Marital Status_ Married-civ-spouse,Marital Sta...
# 5672   Marital Status_ Married-civ-spouse,Age,Relatio...
# 6880   Marital Status_ Married-civ-spouse,Relationshi...
# 1603   Marital Status_ Married-civ-spouse,Relationshi...
# 5310   Marital Status_ Married-civ-spouse,Relationshi...
# 12257  Marital Status_ Married-civ-spouse,Relationshi...
# 13219  Marital Status_ Married-civ-spouse,Marital Sta...
# 3792   Education-Num,Capital Gain,Hours per week,Occu...
# 5224   Marital Status_ Married-civ-spouse,Marital Sta...
# 10941  Age,Education-Num,Relationship_ Husband,Educat...
# 13564  Marital Status_ Married-civ-spouse,Relationshi...
# 6223   Education-Num,Capital Gain,Hours per week,Occu...
# 2578   Marital Status_ Married-civ-spouse,Age,Relatio...
# 5596   Education-Num,Education_ HS-grad,Capital Gain,...
# 13493  Occupation_ Other-service,Relationship_ Husban...
# 8861   Hours per week,Occupation_ Exec-managerial,Rac...
# 11958  Capital Gain,Occupation_ Exec-managerial,Capit...
# 6682   Age,Marital Status_ Married-civ-spouse,Marital...
# 9231   Education-Num,Education_ HS-grad,Capital Gain,...
#
# [100 rows x 19 columns]

# %% [markdown]
# ## Let's check! local reason codes

# %%
# Check shapley values (first row)
index=df_shap_values.index[0]
from IPython.display import display

pd.set_option('display.max_colwidth', 200)
display(df_explanation[["TOP_POS","TOP_NEG"]].loc[[index]].T)

shap.summary_plot(df_shap_values.loc[[index]].values,
                  X_explanation_rows.loc[[index]].values,
                  feature_names=feature_names)
# Out:
#                                                                                                                   3862
# TOP_POS          Marital Status_ Never-married,Age,Relationship_ Own-child,Education_ HS-grad,Occupation_ Tech-support
# TOP_NEG  Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Unmarried,Sex,Marital Status_ Divorced

# %% [markdown]
# ## Global Shapley importances

# %%
shap.summary_plot(df_shap_values.values, X_explanation_rows,feature_names=feature_names)

# %% [markdown]
# # Prepare dataframe for Dash

# %%
# Add index, we'll use it on dash back & forward (hidden)
df_explanation["index"]=df_explanation.index.values
df_explanation
# Out:
#        Age          Workclass  Final Weight      Education  Education-Num  \
# 3862    43            Private        175133   Some-college             10
# 5769    43            Private        157473        HS-grad              9
# 1251    21                  ?        197583   Some-college             10
# 2321    35        Federal-gov        403489        HS-grad              9
# 11543   57   Self-emp-not-inc        256630      Bachelors             13
# 4288    25            Private        150312        HS-grad              9
# 3704    43            Private         72338        Masters             14
# 13347   25            Private        108838      Bachelors             13
# 3450    53            Private        185283        HS-grad              9
# 398     36            Private        116358        Masters             14
# 6500    36            Private         65382        HS-grad              9
# 8060    34            Private        127875      Bachelors             13
# 5293    30            Private        136331        HS-grad              9
# 8164    47            Private        275163        HS-grad              9
# 15521   42   Self-emp-not-inc         34722        HS-grad              9
# 1161    38            Private        258339      Assoc-voc             11
# 14700   24            Private        231261           12th              8
# 607     32          Local-gov        267859   Some-college             10
# 3228    34                  ?         73296           11th              7
# 10133   47            Private        183186      Bachelors             13
# 11872   30          Local-gov        325658        HS-grad              9
# 920     45            Private        167159      Bachelors             13
# 4785    37            Private        207066        Masters             14
# 7147    26            Private        272865        HS-grad              9
# 15927   24            Private        362059           12th              8
# 2196    25            Private        179255   Some-college             10
# 992     59       Self-emp-inc         77816    Prof-school             15
# 2174    17            Private        138507           10th              6
# 4319    39   Self-emp-not-inc        245361   Some-college             10
# 11919   50            Private         69477           10th              6
# ...    ...                ...           ...            ...            ...
# 8232    64   Self-emp-not-inc        198466        HS-grad              9
# 5238    63            Private        210350        5th-6th              3
# 4130    50            Private        240374        Masters             14
# 1517    69   Self-emp-not-inc        199829      Bachelors             13
# 4911    19            Private       1047822           11th              7
# 6120    26            Private        331861      Bachelors             13
# 10224   54            Private        283725        Masters             14
# 3475    53            Private        108435        HS-grad              9
# 6585    32            Private        262092      Bachelors             13
# 7266    51                  ?        156877            9th              5
# 4805    43            Private        183342      Bachelors             13
# 10640   30            Private        177675        HS-grad              9
# 5672    17            Private        165018           10th              6
# 6880    52            Private        236222        HS-grad              9
# 1603    45            Private        180010        HS-grad              9
# 5310    43        Federal-gov        183608        HS-grad              9
# 12257   30   Self-emp-not-inc        247328      Assoc-voc             11
# 13219   28            Private        105422   Some-college             10
# 3792    49            Private        186256   Some-college             10
# 5224    48            Private        443377        Masters             14
# 10941   24                  ?         61791            9th              5
# 13564   34          State-gov         49539        HS-grad              9
# 6223    53            Private        168723     Assoc-acdm             12
# 2578    24            Private        236601   Some-college             10
# 5596    39            Private        112077        HS-grad              9
# 13493   38            Private        191455        HS-grad              9
# 8861    44        Federal-gov        320451      Bachelors             13
# 11958   41          Local-gov        103614      Bachelors             13
# 6682    25            Private        335522            9th              5
# 9231    34            Private        150154        HS-grad              9
#
#             Marital Status          Occupation     Relationship  \
# 3862              Divorced        Tech-support        Unmarried
# 5769         Never-married               Sales    Not-in-family
# 1251         Never-married                   ?        Own-child
# 2321         Never-married        Adm-clerical        Own-child
# 11543             Divorced               Sales    Not-in-family
# 4288         Never-married   Machine-op-inspct    Not-in-family
# 3704    Married-civ-spouse        Tech-support          Husband
# 13347        Never-married        Adm-clerical    Not-in-family
# 3450    Married-civ-spouse        Craft-repair          Husband
# 398     Married-civ-spouse     Exec-managerial          Husband
# 6500    Married-civ-spouse        Craft-repair          Husband
# 8060         Never-married        Adm-clerical    Not-in-family
# 5293    Married-civ-spouse        Adm-clerical          Husband
# 8164    Married-civ-spouse        Craft-repair          Husband
# 15521   Married-civ-spouse               Sales          Husband
# 1161    Married-civ-spouse       Other-service          Husband
# 14700   Married-civ-spouse        Adm-clerical          Husband
# 607     Married-civ-spouse     Protective-serv          Husband
# 3228         Never-married                   ?    Not-in-family
# 10133   Married-civ-spouse     Exec-managerial          Husband
# 11872   Married-civ-spouse     Exec-managerial          Husband
# 920     Married-civ-spouse        Craft-repair          Husband
# 4785    Married-civ-spouse      Prof-specialty          Husband
# 7147    Married-civ-spouse        Craft-repair          Husband
# 15927        Never-married        Craft-repair        Own-child
# 2196         Never-married        Adm-clerical        Own-child
# 992     Married-civ-spouse      Prof-specialty          Husband
# 2174         Never-married   Handlers-cleaners        Own-child
# 4319         Never-married      Prof-specialty        Own-child
# 11919   Married-civ-spouse     Farming-fishing          Husband
# ...                    ...                 ...              ...
# 8232               Widowed               Sales    Not-in-family
# 5238    Married-civ-spouse   Machine-op-inspct          Husband
# 4130    Married-civ-spouse     Exec-managerial          Husband
# 1517    Married-civ-spouse     Exec-managerial          Husband
# 4911         Never-married               Sales        Unmarried
# 6120         Never-married        Craft-repair    Not-in-family
# 10224             Divorced               Sales    Not-in-family
# 3475    Married-civ-spouse        Tech-support          Husband
# 6585    Married-civ-spouse      Prof-specialty          Husband
# 7266             Separated                   ?    Not-in-family
# 4805    Married-civ-spouse        Adm-clerical          Husband
# 10640        Never-married   Machine-op-inspct   Other-relative
# 5672         Never-married               Sales        Own-child
# 6880              Divorced     Exec-managerial    Not-in-family
# 1603              Divorced               Sales        Own-child
# 5310              Divorced        Adm-clerical    Not-in-family
# 12257            Separated               Sales    Not-in-family
# 13219        Never-married    Transport-moving    Not-in-family
# 3792    Married-civ-spouse        Adm-clerical          Husband
# 5224         Never-married      Prof-specialty    Not-in-family
# 10941   Married-civ-spouse                   ?             Wife
# 13564        Never-married       Other-service        Own-child
# 6223    Married-civ-spouse        Tech-support          Husband
# 2578              Divorced   Machine-op-inspct    Not-in-family
# 5596    Married-civ-spouse        Craft-repair          Husband
# 13493   Married-civ-spouse       Other-service             Wife
# 8861    Married-civ-spouse      Prof-specialty          Husband
# 11958   Married-civ-spouse      Prof-specialty          Husband
# 6682         Never-married   Handlers-cleaners    Not-in-family
# 9231    Married-civ-spouse        Craft-repair          Husband
#
#                       Race      Sex  Capital Gain  Capital Loss  \
# 3862                 Black   Female             0             0
# 5769                 White   Female             0             0
# 1251                 White   Female             0             0
# 2321                 White     Male             0             0
# 11543                White     Male             0             0
# 4288                 White     Male             0             0
# 3704    Asian-Pac-Islander     Male             0             0
# 13347                White   Female             0             0
# 3450                 White     Male             0             0
# 398     Asian-Pac-Islander     Male             0             0
# 6500                 White     Male             0             0
# 8060                 White   Female             0             0
# 5293                 White     Male             0             0
# 8164                 White     Male             0             0
# 15521                White     Male             0             0
# 1161                 White     Male             0             0
# 14700                White     Male             0             0
# 607                  White     Male             0             0
# 3228                 Black   Female             0             0
# 10133                White     Male             0             0
# 11872                White     Male             0             0
# 920                  White     Male             0             0
# 4785                 White     Male             0             0
# 7147                 White     Male             0             0
# 15927                White     Male             0             0
# 2196                 White   Female             0             0
# 992                  White     Male         99999             0
# 2174                 White     Male             0             0
# 4319                 White   Female             0             0
# 11919                White     Male             0             0
# ...                    ...      ...           ...           ...
# 8232                 White   Female             0             0
# 5238                 Other     Male             0             0
# 4130                 White     Male             0             0
# 1517                 White     Male             0          1258
# 4911                 White   Female             0             0
# 6120                 White     Male             0             0
# 10224                White   Female             0             0
# 3475                 White     Male             0             0
# 6585                 White     Male          7298             0
# 7266                 White     Male             0             0
# 4805                 White     Male             0             0
# 10640                White     Male             0             0
# 5672                 White   Female             0             0
# 6880                 White   Female             0             0
# 1603                 White   Female             0             0
# 5310                 Black   Female             0             0
# 12257                White     Male             0             0
# 13219                White     Male             0             0
# 3792                 White     Male             0             0
# 5224                 White     Male             0             0
# 10941                White   Female             0             0
# 13564                White   Female             0             0
# 6223                 White     Male             0             0
# 2578                 White     Male             0          2339
# 5596                 White     Male             0             0
# 13493                White   Female             0             0
# 8861    Asian-Pac-Islander     Male         15024             0
# 11958                White     Male             0             0
# 6682                 White     Male             0             0
# 9231                 White     Male             0             0
#
#        Hours per week         Country   Income  SCORE_PROB  SCORE_RATIO  \
# 3862               35   United-States   <=50K.        0.18         0.36
# 5769               40   United-States   <=50K.        0.18         0.36
# 1251               40   United-States   <=50K.        0.07         0.13
# 2321               40   United-States   <=50K.        0.15         0.31
# 11543              60          Canada    >50K.        0.47         0.95
# 4288               40   United-States   <=50K.        0.13         0.25
# 3704               40   United-States    >50K.        0.74         1.48
# 13347              40   United-States   <=50K.        0.21         0.42
# 3450               45   United-States    >50K.        0.61         1.23
# 398                45           India   <=50K.        0.80         1.60
# 6500               50   United-States   <=50K.        0.61         1.22
# 8060               20   United-States   <=50K.        0.28         0.57
# 5293               40   United-States   <=50K.        0.57         1.15
# 8164               45   United-States   <=50K.        0.61         1.23
# 15521              60   United-States   <=50K.        0.62         1.23
# 1161               70            Iran   <=50K.        0.58         1.16
# 14700              50   United-States   <=50K.        0.52         1.04
# 607                50            Cuba   <=50K.        0.65         1.30
# 3228               40   United-States   <=50K.        0.15         0.30
# 10133              60   United-States    >50K.        0.81         1.61
# 11872              40   United-States   <=50K.        0.64         1.28
# 920                40   United-States   <=50K.        0.73         1.46
# 4785               70   United-States   <=50K.        0.80         1.60
# 7147               40   United-States   <=50K.        0.48         0.96
# 15927              32   United-States   <=50K.        0.08         0.16
# 2196               25   United-States   <=50K.        0.07         0.13
# 992                40   United-States    >50K.        0.88         1.75
# 2174               12   United-States   <=50K.        0.06         0.12
# 4319               10   United-States   <=50K.        0.19         0.38
# 11919              45   United-States   <=50K.        0.55         1.09
# ...               ...             ...      ...         ...          ...
# 8232               70   United-States   <=50K.        0.29         0.58
# 5238               32          Mexico   <=50K.        0.43         0.86
# 4130               50   United-States    >50K.        0.82         1.65
# 1517               40   United-States   <=50K.        0.77         1.54
# 4911               25   United-States   <=50K.        0.10         0.19
# 6120               50         England   <=50K.        0.31         0.61
# 10224              40   United-States   <=50K.        0.40         0.80
# 3475               40           Italy   <=50K.        0.60         1.20
# 6585               50   United-States    >50K.        0.87         1.73
# 7266               60   United-States   <=50K.        0.28         0.57
# 4805               40   United-States    >50K.        0.73         1.46
# 10640              40   United-States   <=50K.        0.18         0.36
# 5672               10   United-States   <=50K.        0.06         0.12
# 6880               40   United-States   <=50K.        0.28         0.56
# 1603               40   United-States   <=50K.        0.18         0.37
# 5310               40   United-States   <=50K.        0.20         0.39
# 12257              40          Mexico   <=50K.        0.27         0.54
# 13219              50   United-States   <=50K.        0.26         0.51
# 3792               40   United-States   <=50K.        0.62         1.25
# 5224               60   United-States   <=50K.        0.50         1.00
# 10941              40   United-States   <=50K.        0.41         0.81
# 13564              20   United-States   <=50K.        0.09         0.19
# 6223               40   United-States    >50K.        0.64         1.28
# 2578               43   United-States   <=50K.        0.32         0.64
# 5596               40   United-States   <=50K.        0.59         1.17
# 13493              10   United-States   <=50K.        0.45         0.89
# 8861               40     Philippines    >50K.        0.85         1.70
# 11958              45   United-States    >50K.        0.79         1.57
# 6682               40          Mexico   <=50K.        0.11         0.23
# 9231               50   United-States    >50K.        0.61         1.21
#
#                                                                                                                                        TOP_POS  \
# 3862                                     Marital Status_ Never-married,Age,Relationship_ Own-child,Education_ HS-grad,Occupation_ Tech-support
# 5769                                    Age,Relationship_ Own-child,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced
# 1251                 Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced,Relationship_ Not-in-family
# 2321                                                               Age,Sex,Workclass_ Federal-gov,Workclass_ Private,Occupation_ Other-service
# 11543                                                      Education-Num,Hours per week,Education_ Bachelors,Age,Marital Status_ Never-married
# 4288                                    Relationship_ Own-child,Sex,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced
# 3704                   Marital Status_ Married-civ-spouse,Education-Num,Education_ Masters,Relationship_ Husband,Marital Status_ Never-married
# 13347                                  Education-Num,Education_ Bachelors,Relationship_ Own-child,Education_ HS-grad,Occupation_ Other-service
# 3450                                 Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# 398                      Education-Num,Marital Status_ Married-civ-spouse,Occupation_ Exec-managerial,Education_ Masters,Relationship_ Husband
# 6500                                 Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# 8060                                                         Education-Num,Education_ Bachelors,Age,Relationship_ Own-child,Education_ HS-grad
# 5293                    Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Sex,Relationship_ Not-in-family
# 8164                                 Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# 15521                                Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# 1161                                 Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# 14700            Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Relationship_ Own-child
# 607                                  Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Sex
# 3228                                          Age,Relationship_ Own-child,Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried
# 10133                  Marital Status_ Married-civ-spouse,Education-Num,Occupation_ Exec-managerial,Relationship_ Husband,Education_ Bachelors
# 11872                   Marital Status_ Married-civ-spouse,Occupation_ Exec-managerial,Relationship_ Husband,Marital Status_ Never-married,Sex
# 920                  Marital Status_ Married-civ-spouse,Education-Num,Relationship_ Husband,Education_ Bachelors,Marital Status_ Never-married
# 4785                      Education-Num,Marital Status_ Married-civ-spouse,Education_ Masters,Relationship_ Husband,Occupation_ Prof-specialty
# 7147                        Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Relationship_ Own-child,Sex
# 15927                                        Sex,Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced
# 2196                 Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced,Relationship_ Not-in-family
# 992                            Capital Gain,Education-Num,Marital Status_ Married-civ-spouse,Education_ Prof-school,Occupation_ Prof-specialty
# 2174                                         Sex,Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced
# 4319                                   Occupation_ Prof-specialty,Age,Education_ HS-grad,Workclass_ Self-emp-not-inc,Occupation_ Other-service
# 11919                                Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
# ...                                                                                                                                        ...
# 8232                                        Hours per week,Marital Status_ Never-married,Age,Relationship_ Own-child,Occupation_ Other-service
# 5238                                            Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Age,Sex
# 4130                     Education-Num,Marital Status_ Married-civ-spouse,Occupation_ Exec-managerial,Education_ Masters,Relationship_ Husband
# 1517                   Marital Status_ Married-civ-spouse,Education-Num,Occupation_ Exec-managerial,Relationship_ Husband,Education_ Bachelors
# 4911                 Relationship_ Own-child,Education_ HS-grad,Occupation_ Other-service,Relationship_ Not-in-family,Marital Status_ Divorced
# 6120                                                             Education-Num,Hours per week,Education_ Bachelors,Relationship_ Own-child,Sex
# 10224                                                    Education-Num,Education_ Masters,Marital Status_ Never-married,Age,Education_ HS-grad
# 3475                                            Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Age,Sex
# 6585                                  Capital Gain,Marital Status_ Married-civ-spouse,Education-Num,Relationship_ Husband,Education_ Bachelors
# 7266                                                              Hours per week,Age,Marital Status_ Never-married,Sex,Relationship_ Own-child
# 4805                 Marital Status_ Married-civ-spouse,Education-Num,Relationship_ Husband,Education_ Bachelors,Marital Status_ Never-married
# 10640                                                    Sex,Age,Relationship_ Own-child,Occupation_ Other-service,Relationship_ Not-in-family
# 5672                 Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried,Marital Status_ Divorced,Relationship_ Not-in-family
# 6880                             Occupation_ Exec-managerial,Marital Status_ Never-married,Age,Relationship_ Own-child,Relationship_ Unmarried
# 1603                           Marital Status_ Never-married,Age,Relationship_ Not-in-family,Relationship_ Unmarried,Occupation_ Other-service
# 5310                                       Marital Status_ Never-married,Age,Workclass_ Federal-gov,Relationship_ Own-child,Workclass_ Private
# 12257                                                         Marital Status_ Never-married,Sex,Relationship_ Own-child,Education_ HS-grad,Age
# 13219                                                  Hours per week,Sex,Relationship_ Own-child,Education_ HS-grad,Occupation_ Other-service
# 3792                                            Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Age,Sex
# 5224                                                            Education-Num,Education_ Masters,Occupation_ Prof-specialty,Hours per week,Age
# 10941  Marital Status_ Married-civ-spouse,Relationship_ Wife,Marital Status_ Never-married,Relationship_ Own-child,Relationship_ Not-in-family
# 13564                                      Age,Workclass_ Private,Relationship_ Unmarried,Relationship_ Not-in-family,Marital Status_ Divorced
# 6223                                            Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Age,Sex
# 2578                                                     Capital Loss,Hours per week,Marital Status_ Never-married,Sex,Relationship_ Own-child
# 5596                                            Marital Status_ Married-civ-spouse,Relationship_ Husband,Marital Status_ Never-married,Age,Sex
# 13493                      Marital Status_ Married-civ-spouse,Relationship_ Wife,Marital Status_ Never-married,Age,Relationship_ Not-in-family
# 8861                            Capital Gain,Marital Status_ Married-civ-spouse,Education-Num,Relationship_ Husband,Occupation_ Prof-specialty
# 11958                   Marital Status_ Married-civ-spouse,Education-Num,Relationship_ Husband,Occupation_ Prof-specialty,Education_ Bachelors
# 6682                                          Relationship_ Own-child,Sex,Education_ HS-grad,Occupation_ Other-service,Relationship_ Unmarried
# 9231                                 Marital Status_ Married-civ-spouse,Relationship_ Husband,Hours per week,Marital Status_ Never-married,Age
#
#                                                                                                                                         TOP_NEG  \
# 3862                              Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Unmarried,Sex,Marital Status_ Divorced
# 5769                                   Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Sex,Education-Num
# 1251                         Marital Status_ Married-civ-spouse,Age,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband
# 2321               Marital Status_ Married-civ-spouse,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband,Education-Num
# 11543                Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Not-in-family,Marital Status_ Divorced,Capital Gain
# 4288                     Marital Status_ Married-civ-spouse,Age,Marital Status_ Never-married,Relationship_ Husband,Relationship_ Not-in-family
# 3704                                             Capital Gain,Race_ White,Hours per week,Occupation_ Exec-managerial,Occupation_ Prof-specialty
# 13347                                            Marital Status_ Married-civ-spouse,Age,Marital Status_ Never-married,Relationship_ Husband,Sex
# 3450                                             Education-Num,Education_ HS-grad,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 398                                             Capital Gain,Race_ White,Education_ Bachelors,Occupation_ Prof-specialty,Country_ United-States
# 6500                                             Education-Num,Education_ HS-grad,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 8060                                  Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Sex,Hours per week
# 5293                                                   Education-Num,Education_ HS-grad,Capital Gain,Hours per week,Occupation_ Exec-managerial
# 8164                                             Education-Num,Education_ HS-grad,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 15521                                            Education-Num,Education_ HS-grad,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 1161                                      Occupation_ Other-service,Education-Num,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 14700                                                           Age,Education-Num,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
# 607                                      Education-Num,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors,Occupation_ Prof-specialty
# 3228                                   Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Education-Num,Sex
# 10133                                                Capital Gain,Occupation_ Prof-specialty,Education_ Masters,Capital Loss,Relationship_ Wife
# 11872                                                         Education-Num,Education_ HS-grad,Capital Gain,Hours per week,Education_ Bachelors
# 920                                 Capital Gain,Hours per week,Occupation_ Exec-managerial,Occupation_ Prof-specialty,Occupation_ Craft-repair
# 4785                                              Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors,Capital Loss,Relationship_ Wife
# 7147                                                                           Age,Education-Num,Education_ HS-grad,Capital Gain,Hours per week
# 15927                        Marital Status_ Married-civ-spouse,Relationship_ Own-child,Age,Marital Status_ Never-married,Relationship_ Husband
# 2196                         Marital Status_ Married-civ-spouse,Relationship_ Own-child,Marital Status_ Never-married,Age,Relationship_ Husband
# 992                                             Hours per week,Occupation_ Exec-managerial,Education_ Bachelors,Capital Loss,Education_ Masters
# 2174                         Age,Marital Status_ Married-civ-spouse,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband
# 4319                         Marital Status_ Married-civ-spouse,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband,Sex
# 11919                                        Education-Num,Education_ 10th,Occupation_ Farming-fishing,Capital Gain,Occupation_ Exec-managerial
# ...                                                                                                                                         ...
# 8232                                     Marital Status_ Married-civ-spouse,Relationship_ Husband,Sex,Relationship_ Not-in-family,Education-Num
# 5238                                              Country_ Mexico,Education-Num,Hours per week,Education_ 5th-6th,Occupation_ Machine-op-inspct
# 4130                                               Capital Gain,Education_ Bachelors,Occupation_ Prof-specialty,Capital Loss,Relationship_ Wife
# 1517                                                     Capital Gain,Hours per week,Occupation_ Prof-specialty,Capital Loss,Education_ Masters
# 4911                                   Marital Status_ Married-civ-spouse,Age,Marital Status_ Never-married,Relationship_ Husband,Education-Num
# 6120                     Age,Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Relationship_ Not-in-family
# 10224                         Marital Status_ Married-civ-spouse,Relationship_ Husband,Sex,Relationship_ Not-in-family,Marital Status_ Divorced
# 3475                                                   Education-Num,Education_ HS-grad,Capital Gain,Hours per week,Occupation_ Exec-managerial
# 6585                                      Occupation_ Exec-managerial,Capital Loss,Education_ Masters,Relationship_ Wife,Education_ Prof-school
# 7266               Marital Status_ Married-civ-spouse,Relationship_ Husband,Education-Num,Relationship_ Not-in-family,Marital Status_ Separated
# 4805                                Capital Gain,Hours per week,Occupation_ Adm-clerical,Occupation_ Exec-managerial,Occupation_ Prof-specialty
# 10640         Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Relationship_ Other-relative,Education-Num
# 5672                         Marital Status_ Married-civ-spouse,Age,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband
# 6880                          Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Not-in-family,Sex,Marital Status_ Divorced
# 1603                              Marital Status_ Married-civ-spouse,Relationship_ Own-child,Relationship_ Husband,Sex,Marital Status_ Divorced
# 5310                          Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Not-in-family,Sex,Marital Status_ Divorced
# 12257            Marital Status_ Married-civ-spouse,Relationship_ Husband,Relationship_ Not-in-family,Country_ Mexico,Marital Status_ Separated
# 13219          Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Relationship_ Not-in-family,Education-Num
# 3792                                                 Education-Num,Capital Gain,Hours per week,Occupation_ Exec-managerial,Education_ Bachelors
# 5224            Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Relationship_ Not-in-family,Capital Gain
# 10941                                                                                Age,Education-Num,Relationship_ Husband,Education_ 9th,Sex
# 13564  Marital Status_ Married-civ-spouse,Relationship_ Own-child,Marital Status_ Never-married,Relationship_ Husband,Occupation_ Other-service
# 6223                                                 Education-Num,Capital Gain,Hours per week,Occupation_ Exec-managerial,Education_ Bachelors
# 2578                          Marital Status_ Married-civ-spouse,Age,Relationship_ Husband,Relationship_ Not-in-family,Marital Status_ Divorced
# 5596                                                   Education-Num,Education_ HS-grad,Capital Gain,Hours per week,Occupation_ Exec-managerial
# 13493                                                          Occupation_ Other-service,Relationship_ Husband,Hours per week,Education-Num,Sex
# 8861                                                 Hours per week,Occupation_ Exec-managerial,Race_ White,Country_ United-States,Capital Loss
# 11958                                               Capital Gain,Occupation_ Exec-managerial,Capital Loss,Education_ Masters,Relationship_ Wife
# 6682                                   Age,Marital Status_ Married-civ-spouse,Marital Status_ Never-married,Relationship_ Husband,Education-Num
# 9231                                             Education-Num,Education_ HS-grad,Capital Gain,Occupation_ Exec-managerial,Education_ Bachelors
#
#        index
# 3862    3862
# 5769    5769
# 1251    1251
# 2321    2321
# 11543  11543
# 4288    4288
# 3704    3704
# 13347  13347
# 3450    3450
# 398      398
# 6500    6500
# 8060    8060
# 5293    5293
# 8164    8164
# 15521  15521
# 1161    1161
# 14700  14700
# 607      607
# 3228    3228
# 10133  10133
# 11872  11872
# 920      920
# 4785    4785
# 7147    7147
# 15927  15927
# 2196    2196
# 992      992
# 2174    2174
# 4319    4319
# 11919  11919
# ...      ...
# 8232    8232
# 5238    5238
# 4130    4130
# 1517    1517
# 4911    4911
# 6120    6120
# 10224  10224
# 3475    3475
# 6585    6585
# 7266    7266
# 4805    4805
# 10640  10640
# 5672    5672
# 6880    6880
# 1603    1603
# 5310    5310
# 12257  12257
# 13219  13219
# 3792    3792
# 5224    5224
# 10941  10941
# 13564  13564
# 6223    6223
# 2578    2578
# 5596    5596
# 13493  13493
# 8861    8861
# 11958  11958
# 6682    6682
# 9231    9231
#
# [100 rows x 20 columns]

# %% [markdown]
# # Dash

# %%
import os
from IPython.display import display,display_html
# From awesome dash intro repo by Kevin Mader
# A quick intro to Dash made for the PyData event in Zurich
# https://github.com/4QuantOSS/DashIntro 

# Can use Jupyter nbserverproxy extension (available at /.../proxy/<port>)

def show_app(app, port = 10001, 
             width = 700, 
             height = 350, 
             offline = False,
            in_binder = None):
    in_binder ='JUPYTERHUB_SERVICE_PREFIX' in os.environ if in_binder is None else in_binder
    if in_binder:
        base_prefix = '{}proxy/{}/'.format(os.environ['JUPYTERHUB_SERVICE_PREFIX'], port)
        url = 'https://hub.mybinder.org{}'.format(base_prefix)
        app.config.requests_pathname_prefix = base_prefix
    else:
        url = 'http://localhost:%d' % port
    iframe = '<a href="{url}" target="_new">Open in new window</a><hr><iframe src="{url}" width={width} height={height}></iframe>'.format(url = url, 
                                                                                  width = width, 
                                                                                  height = height)

    iframe = '<a href="{url}" target="_new">Open in new window</a><hr>'.format(url = url, 
                                                                                  width = width, 
                                                                                  height = height)

    display_html(iframe, raw = True)
    if offline:
        app.css.config.serve_locally = True
        app.scripts.config.serve_locally = True
        
    return app.run_server(debug=False, # needs to be false in Jupyter
                          host = '0.0.0.0',
                          port=port)

# %%
import sklearn.metrics as metrics
import plotly.graph_objs as go

def shap_local_importances(row_index,max_features=10):
    X_shap=X_explanation_rows.loc[[row_index],:]
    
    shap_values=df_shap_values.loc[[row_index]].values
    
    index=0

    # Create more friendly X axis, like feature=<feature value for that record>
    feature_names=X_shap.columns+"="+X_shap.iloc[[index],:].T.iloc[:,0].values.round(4).astype("str")
    
    df_row_shap=pd.DataFrame(shap_values[0,:],feature_names).reset_index()
    df_row_shap.columns=["feature","shapley"]
    df_row_shap["custom_data"]=X_shap.columns+"|"+str(row_index)
    df_row_shap["abs_shapley"]=df_row_shap.shapley.abs()
    df_row_shap.sort_values("abs_shapley",ascending=False,inplace=True)
    
    # Need to check plotly how to reverse axis, hacking for now, sorry!
    df_top_features=df_row_shap.head(max_features).sort_values("abs_shapley",ascending=True)
    
    figure={
            'data': [
                {
                    'x':  df_top_features.shapley.values,
                    'y': df_top_features.feature.values,
                    'customdata': df_top_features.custom_data.values,
                    'name': 'Local reason codes',
                    'mode': 'markers',
                    'marker': {'size': 10}
                }
            ],
            'layout':{
                "autosize":False,
                    "width":370,
                    "height":450,
                    "margin":go.Margin(
                        l=150,
                        r=50,
                        b=40,
                        t=0,
                      #  pad=50
                  ),
            }
        }
        
    figure = go.Figure(figure)
        
    return figure

# Test
shap_local_importances(X_explanation_rows.index[0])
# Out:
# {'data': [{'type': 'scatter',
#    'x': array([-0.01439472,  0.01703223,  0.01792654, -0.02096019, -0.02456284,
#           -0.02567955, -0.0369102 , -0.04613566, -0.05215561, -0.09367288]),
#    'y': array(['Capital Gain=0.0', 'Age=43.0',
#           'Marital Status_ Never-married=0.0', 'Hours per week=35.0',
#           'Education-Num=10.0', 'Marital Status_ Divorced=1.0', 'Sex=0.0',
#           'Relationship_ Unmarried=1.0', 'Relationship_ Husband=0.0',
#           'Marital Status_ Married-civ-spouse=0.0'], dtype=object),
#    'customdata': array(['Capital Gain|3862', 'Age|3862',
#           'Marital Status_ Never-married|3862', 'Hours per week|3862',
#           'Education-Num|3862', 'Marital Status_ Divorced|3862', 'Sex|3862',
#           'Relationship_ Unmarried|3862', 'Relationship_ Husband|3862',
#           'Marital Status_ Married-civ-spouse|3862'], dtype=object),
#    'name': 'Local reason codes',
#    'mode': 'markers',
#    'marker': {'size': 10}}],
#  'layout': {'autosize': False,
#   'width': 370,
#   'height': 450,
#   'margin': {'l': 150, 'r': 50, 'b': 40, 't': 0}}}

# %%
import sklearn.metrics as metrics
import plotly.graph_objs as go

def shap_detail(row_index,feature):
    feature_shapley_values = df_shap_values[feature].values
    feature_values = X_explanation_rows[feature].values
    
    #friendly title feature=<feature value for that row>
    title="{0}={1}".format(feature,X_explanation_rows.loc[row_index][feature])
    
    figure={
            # All data points here
            'data': [

                {
                    'x':  feature_values,
                    'y': feature_shapley_values,
                    'name': 'Trace 1',
                    'mode': 'markers',
                    'marker': {'size': 5}
                },
                
                
            ],
            # Add annotation to highlight current feature value & position
            'layout':{
                "annotations":[
                        dict(
                            x=X_explanation_rows.loc[row_index][feature],
                            y=df_shap_values.loc[row_index][feature],
                            xref='x',
                            yref='y',
                            text=title,
                            showarrow=True,
                            arrowhead=7,
                            ax=0,
                            ay=-40,
                            bgcolor="red"
                        )
                    ],
                 #"title":title,
                "autosize":False,
                    "width":250,
                    "height":420,
                    "margin":go.Margin(
                        l=20,
                        r=10,
                        b=80,
                        t=20,
                        pad=60
                  ),
            },
            
        }
        
    figure = go.Figure(figure)
        
    return figure

# Test
shap_detail(X_explanation_rows.index[0],"Age")
# Out:
# {'data': [{'type': 'scatter',
#    'x': array([43., 43., 21., 35., 57., 25., 43., 25., 53., 36., 36., 34., 30.,
#           47., 42., 38., 24., 32., 34., 47., 30., 45., 37., 26., 24., 25.,
#           59., 17., 39., 50., 27., 34., 32., 36., 26., 81., 20., 54., 40.,
#           69., 32., 34., 27., 68., 43., 40., 31., 23., 36., 40., 38., 40.,
#           21., 26., 21., 23., 29., 27., 35., 65., 22., 19., 37., 62., 82.,
#           55., 50., 24., 36., 41., 64., 63., 50., 69., 19., 26., 54., 53.,
#           32., 51., 43., 30., 17., 52., 45., 43., 30., 28., 49., 48., 24.,
#           34., 53., 24., 39., 38., 44., 41., 25., 34.]),
#    'y': array([ 0.01703223,  0.01977102, -0.0670918 ,  0.01442819,  0.02009508,
#           -0.06885126,  0.01869581, -0.0715859 ,  0.01994301,  0.01660083,
#            0.01873743,  0.01603547,  0.00688914,  0.01990494,  0.01913423,
#            0.0182115 , -0.08551802,  0.00998172,  0.01254701,  0.01775782,
#            0.00742088,  0.01847655,  0.01797473, -0.08510267, -0.06954   ,
#           -0.06205618,  0.01641371, -0.07237548,  0.02071445,  0.01972022,
#           -0.08353217,  0.01290433,  0.00867785,  0.01741499, -0.08400893,
#            0.01907258, -0.06978547,  0.01994538,  0.01655402,  0.01581576,
#            0.01346973,  0.01216489, -0.07522834,  0.01821607,  0.01807966,
#            0.01822922,  0.00822116, -0.07891605,  0.01878593,  0.01604443,
#            0.0182227 ,  0.01847874, -0.0710751 , -0.06432873, -0.06568187,
#           -0.09068856, -0.00610531, -0.05611312,  0.01307151,  0.01356808,
#           -0.06738893, -0.07312806,  0.01772467,  0.01746948,  0.01533144,
#            0.02056417,  0.01694866, -0.07922418,  0.01968648,  0.01982065,
#            0.01667587,  0.01829858,  0.01863604,  0.01686452, -0.06940952,
#           -0.08235811,  0.01853889,  0.01996294,  0.00978926,  0.02002935,
#            0.01839734,  0.0094161 , -0.06822265,  0.01746755,  0.01780894,
#            0.01570347,  0.00745457, -0.0144802 ,  0.02018194,  0.02385846,
#           -0.07660734,  0.0127289 ,  0.01987084, -0.07192534,  0.01950948,
#            0.01634011,  0.01609558,  0.01784701, -0.06795024,  0.01218815]),
#    'name': 'Trace 1',
#    'mode': 'markers',
#    'marker': {'size': 5}}],
#  'layout': {'annotations': [{'x': 43.0,
#     'y': 0.017032234002203103,
#     'xref': 'x',
#     'yref': 'y',
#     'text': 'Age=43.0',
#     'showarrow': True,
#     'arrowhead': 7,
#     'ax': 0,
#     'ay': -40,
#     'bgcolor': 'red'}],
#   'autosize': False,
#   'width': 250,
#   'height': 420,
#   'margin': {'l': 20, 'r': 10, 'b': 80, 't': 20, 'pad': 60}}}

# %%
import dash
from dash.dependencies import Input, Output, State,Event
import dash_core_components as dcc
import dash_html_components as html
import dash_table_experiments as dt
import plotly


APP_NAME='SHAP Dash! Explanations on Dash - DevScope AI Lab'
app = dash.Dash(name=APP_NAME)

# Need this because we'll add some dynamic callbacks
app.config['suppress_callback_exceptions'] = True

# Hide index column
visible_cols=df_explanation.columns.drop(["index"]).values

# Reference: https://github.com/plotly/dash-svm/
external_css = [
    # Normalize the CSS
    "https://cdnjs.cloudflare.com/ajax/libs/normalize/7.0.0/normalize.min.css",
    # Fonts
    "https://fonts.googleapis.com/css?family=Open+Sans|Roboto",
    "https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css",
    # Base Stylesheet, replace this with your own base-styles.css using Rawgit
    "https://rawgit.com/xhlulu/9a6e89f418ee40d02b637a429a876aa9/raw/f3ea10d53e33ece67eb681025cedc83870c9938d/base-styles.css",
    # Custom Stylesheet, replace this with your own custom-styles.css using Rawgit
    "https://cdn.rawgit.com/plotly/dash-svm/bb031580/custom-styles.css"
    #"https://gist.githubusercontent.com/rquintino/f67a1e9f2c13b9b3e0dae35ac6477295/raw/aa6d5c068882584ab2a019c510c32df80fd8c352/shap-dash-custom-styles.css"
]

for css in external_css:
    app.css.append_css({"external_url": css})
    
    
app.layout = html.Div([
    # Reference: https://github.com/plotly/dash-svm/
    # .container class is fixed, .container.scalable is scalable
    html.Div(className="banner", children=[
        html.Div(className='container scalable', children=[
            html.H2(html.A(
                APP_NAME,
                href='https://github.com/DevScope/ai-lab',
                style={
                    'text-decoration': 'none',
                    'color': 'inherit'
                }
            )),

            html.A(
                html.Img(src="https://s3-us-west-1.amazonaws.com/plotly-tutorials/logo/new-branding/dash-logo-by-plotly-stripe-inverted.png"),
                href='https://plot.ly/products/dash/'
            )
        ]),
    ]),
    html.Div(id='body', className='container scalable', children=[
         html.Div([
            html.Div(
                [
                    dt.DataTable(
                        rows=df_explanation.to_dict('records'),
                        editable=False,
                        sortable=True,
                        columns=visible_cols,
                        row_selectable=True,
                        filterable=True,
                        id='score_table'
                        ),
                    html.Button('Explain', id='explain'),
                    html.Button('Clear', id='clear'),
                ],className="five columns"),
             html.Div(
                 [
                        html.Div(id="output",children=[
                            # Needed to add this blank chart on startup, otherwise charts wouldnt load?
                            # Dash tables have similar issue
                            dcc.Graph(
                                id='example-graph',
                                figure={'data': [], 'layout': { }
                            }
                        ),
                        ],style={"padding":"20px"})
                   ],id="results",className="seven columns",style={'height':'500px','overflow-y': 'scroll'})
        ],className="row")
     ])
])

@app.callback(
   Output('score_table', 'selected_row_indices'),
   [Input("clear","n_clicks")])
def click_clear(n_clicks):
    return []

@app.callback(
   Output('output', 'children'),
   [Input("explain","n_clicks")],
    state=[
        State('score_table', 'rows'),
        State('score_table', 'selected_row_indices')
    ])
def explain_selected_rows(n_clicks,rows,selected_row_indices):
    # note: currently, the only way I know to get selected indexes
    # we have to send whole table back from browser to python kernel...
    # new table component is expected this summer by plotly team!
    # https://github.com/plotly/dash-table-experiments/issues/15
    if not rows or len(rows)==0 or not selected_row_indices or len(selected_row_indices)==0:
        return []
    
    selected_row_indices.sort()
    
    # Reconstruct dataframe with original indexes
    df_rows = pd.DataFrame(rows)
    df_rows.index=df_rows["index"]
    
    indexes=df_rows.iloc[selected_row_indices].index
    
    # Check selectd rows on notebook (debug)
    #display(df_rows.loc[indexes])
    
    children=[]
    
    MAX_FEATURES=12
    
    i=0
    for index in indexes:
        i=i+1
        original_index=int(index)
        
        original_row=df_explanation.loc[[original_index]]
        X_original_row=X_explanation_rows.loc[[original_index]]
        
        title=" Age {0} (#)".format(
                             original_row.Age.iloc[0],
                             i+1
                            )
        
        score="{0:.2%} Probability".format(
                             original_row.SCORE_PROB.iloc[0]
                            )
        
        children.append(html.Div([html.H6(title,className="six columns"),
                                 html.H6(score,className="six columns",style={"text-align":"right"})
                                 ],className="row"))
        
        fig_shap=shap_local_importances(original_index,MAX_FEATURES)  
        
        children.append(html.Div([dcc.Graph(id='summary_'+str(i),figure=fig_shap,
                                            className="six columns",
                                            config={ 'displayModeBar': False}),
                                 html.Div(id="detail_"+str(i),className="six columns")
                                 ],className="row"))
    return children

# Ok... more than 100 and this won't work, have to dig deeper...
for i in range(100):    
    @app.callback(
        Output('detail_'+str(i), 'children'),
        [Input('summary_'+str(i), 'clickData')])
    def detail(clickData):
        if not clickData or len(clickData)==0:
            return []
        
        children=[]
        
        # Grab feature and row index from customdata, better way? let me know please.
        point=clickData["points"][0]
        
        feature,row_index=point["customdata"].split("|")
        row_index=int(row_index)
                                                        
        fig_shap=shap_detail(row_index,feature)  
        
        children.append(dcc.Graph(id='detail_chart_'+str(row_index),figure=fig_shap,
                                 config={ 'displayModeBar': False}))
        
        return children

# %%
# use <esc> i+i on Jupyter to quick interrupt & get control back to jupyter
show_app(app)
# Out:
# <a href="http://localhost:10001" target="_new">Open in new window</a><hr>
#  * Running on http://0.0.0.0:10001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Aug/2018 08:43:24] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:43:26] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:43:26] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:43:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:43:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:43:27] "GET /favicon.ico HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:12] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [24/Aug/2018 08:44:16] "POST /_dash-update-component HTTP/1.1" 200 -
